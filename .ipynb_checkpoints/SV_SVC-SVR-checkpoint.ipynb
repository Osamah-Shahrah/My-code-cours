# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
import pandas as pd

# %%
my_data=np.array([[3,2],[6,6],[2.6,3],[7,8],[3.5,5],[6,11]])
my_predict=[0,1,0,1,0,1]


#my_data2=pd.read_csv('house_practice.csv')
#my_data=np.array(my_data2['Size']).reshape(-1, 1)
#my_predict=np.array(my_data2['Price'])



my_model=svm.SVC(kernel='linear',C=1.0)
my_model.fit(my_data,my_predict)
# Out:
# SVC(kernel='linear')

# %%
print("The predict for thes data [0.5,0.8]  is :",my_model.predict([[0.5,0.8]]))
print("The predict for this data [8.5,10] is :",my_model.predict([[8.5,10]]))

plt.scatter(my_data[:,0],my_data[:,0])
plt.scatter(0.5,0.8,c ="r")
plt.scatter(8.5,10,c='r')
plt.show
# Out:
# C:\Users\Osamah\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 print("The predict for thes data [0.5,0.8]  is :",my_model.predict([[2500]]))
#       2 print("The predict for this data [8.5,10] is :",my_model.predict([[200]]))
#       4 plt.scatter(my_data[:,0],my_data[:,0])
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     427         The predicted values.
#     428     """
# --> 429     X = self._validate_for_predict(X)
#     430     predict = self._sparse_predict if self._sparse else self._dense_predict
#     431     return predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:636, in BaseLibSVM._validate_for_predict(self, X)
#     629         raise ValueError(
#     630             "X.shape[1] = %d should be equal to %d, "
#     631             "the number of samples at training time"
#     632             % (X.shape[1], self.shape_fit_[0])
#     633         )
#     634 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     635 # Check that _n_support is consistent with support_vectors
# --> 636 sv = self.support_vectors_
#     637 if not self._sparse and sv.size > 0 and self.n_support_.sum() != sv.shape[0]:
#     638     raise ValueError(
#     639         f"The internal representation of {self.__class__.__name__} was altered"
#     640     )
#
# AttributeError: 'SVC' object has no attribute 'support_vectors_'

# %%
#--------------SVR--------------

# %%
my_model2=svm.SVR(kernel='linear',C=1.0)
my_model2.fit(my_data,my_predict)
pre=my_model2.predict([[0.5,.8]])
pre2=my_model2.predict([[8.5,10]])

# %%
print("The data predict from the this [0.5,.8] data is:",pre)
print("The data predict from the this [8.5,10] data is:",pre2)

plt.scatter(my_data[:,0],my_data[:,1])
plt.scatter(0.5,0.8,c='r')
plt.scatter(8.5,10,c='r')
plt.show
# Out:
# The data predict from the this [0.5,.8] data is: [-0.66959266]
# The data predict from the this [8.5,10] data is: [1.51415098]
# <function matplotlib.pyplot.show(close=None, block=None)>
